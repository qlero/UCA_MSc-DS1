# %% [markdown]
# ## COURSE 1 - Statistical Inference 1

# %% [markdown]
# *October, 15th, 2020*
#
# **Teacher**: Christine Malot

# %%
from IPython.display import Image

# %% [markdown]
# **Remark**: Practice Courses will be covered in Statistical Inference 2

# %% [markdown]
# # Point Estimation
#
# An estimator is a function that takes random variable(s) as inputs.
#
# Let $X_1...X_n$ independent and identically distributed (IID) random variables (RV). We assume that $\forall i \in [1,n]$, $X_i ~ P(\theta)$, with $\theta$ an unknown parameter.
#
# > **Goal**: We want to estimate $\theta$.
# >
# : As such, we consider an estimator $\hat{\theta_n}$, with $\hat{\theta_n} = f(X_1, ..., X_n)$. We also prefer **unbiased estimators**. I.e. $E[\hat{\theta_n}] = \theta$.
#
# We can construct **asymptotically unbiased** estimators, i.e. $E[\hat{\theta_n}] \underset{n\rightarrow\infty}{\rightarrow} \theta$
#
# If we have $X_1, ..., X_n$ IID RV such that $\theta - E[X_1], sigma^2=V[X]$:
#
# - unbiased estimator for $\theta$: $\quad\hat{\theta_n}=\frac{1}{n}.\underset{i=1}{\overset{n}{\sum}}X_i = \bar{X_n}$
#
# - unbiased estimator for $\sigma^2$: $\quad\hat{\sigma^2_n} = \frac{1}{n-1}.\underset{i=1}{\overset{n}{\sum}}(X_i-\bar{X_n})^2$
#
# A second property for estimators is **convergence** or **consistency**. Let $\hat{\theta_n}$ an estimator of $\theta$, we say that $\hat{\theta_n}$ is consistent (or convergence) if:
#
# > $\hat{\theta_n} \underset{P\,or\,AS}{\rightarrow} \theta$
#
# Let $\hat{\theta_n}$ be an estimator of $\theta$. $\hat{\theta_n}$ is consistent if:
#
# - $\theta$ is unbiased
# - $\mathbb{V}[\hat{\theta_n}]\underset{n\rightarrow\infty}{\rightarrow} 0$
# <hr>

# %% [markdown]
# ### Example:
#
# Let $X_1...X_n$ IID RV. We denote by $\theta$ their expectation. We know that $\hat{\theta_n} = \bar{X_n}$ is an unbiased estimator for $\theta$. Is $\hat{\theta_n}$ consistent? **Yes**
#
# $\mathbb{V}[\bar{X_n}] = \mathbb{V}[\frac{1}{n}.\underset{i=1}{\overset{n}{\sum}}] = \frac{1}{n^2}.\mathbb{V}[\underset{i=1}{\overset{n}{\sum}}] = \frac{n}{n^2}.\mathbb{V}[X_i] = \frac{1}{n}.\mathbb{V}[X_n]$
#
# $\mathbb{V}[\bar{X_n}] \underset{n\rightarrow+\infty}{\rightarrow} 0$
#
# Thanks to the previous theorem, we conclude that $\bar{X_n}$ is consistent.
#
# **Remark**: We can also prove that:
#
# - $\hat{\sigma^2} \underset{P}{\rightarrow} \sigma^2$
#
# - $\hat{\sigma^2} \underset{AS}{\rightarrow} \sigma^2$
#
# **Remark 2**: We can get more properties in particular, we have some results about the best unbiased estimator.
#
# If we just consider the family of unbiased estimator of an unknown. If we just consider the family of unbiased estimator of an unknown parameter $\theta$, there exists a 'best estimator' which is the one with the smallest variance.
# <hr>

# %% [markdown]
# The smallest variance is known, this is the **Cramer Rao** bound. This bound is connected with the **Fisher Information**.
#
# Cramer-Rao bound = 1/Fisher Information
# <hr>

# %% [markdown]
# # Construction of an estimator

# %% [markdown]
# There are two main techniques:
#
# - **method of moments**
#
# - **maximum likelihood**

# %% [markdown]
# ### Method of moments
#
# **Remember**: X is a RV, thus:
# - $\mathbb{E}[X^k]$:  **moment of order k**
# - $\mathbb{E}[(X - \mathbb{E}[X])^k]$: **centered moment of order k**
#
# Thanks to this and the **law of large numbers** (LLN), let consider $X_1, ..., X_n$, a n-sample (n IID random variables) with distribution $P_{\theta}$. We want to estimate $\theta$.
#
# **Method**:
#
# 1. We find $k \in \mathbb{N}\ast$ such that $E[X_1^k] = g(\theta)$
# 2. An estimator of $\hat{\theta_n}$ is such that $g(\hat{\theta_n})=\frac{1}{n}\underset{i=1}{\overset{n}{\sum}} X_i^k$
#
# **Explanation**:
#
# We consider $y_1=X_1^k, ..., y_n=X_n^k$ with $y_1, ..., y_n$ IID RV such that $\mathbb{E}[y_1] = g(\theta)$ with $g(\theta)=\mu$ unknown.
#
# $\Rightarrow$ an estimator of $\mu$ is just $\frac{1}{n}\underset{i=1}{\overset{n}{\sum}} X_i^k$
#
# **Remark 1**:
#
# Because of the law of large numbers, we know that $\frac{1}{n}\underset{i=1}{\overset{n}{\sum}} X_i^k \underset{as}{\rightarrow} g(\theta)$

# %% [markdown]
# **Application 1**:
#
# $X_1, ..., X_n$ IID with distribution $U([0,\theta])$. How to estimate $\theta$?
#
# With the method of moments:
#
# $\mathbb{E}[X_1] = \frac{\theta}{2} = g(\theta)$ with $g: \mathbb{R} \rightarrow \mathbb{R}$ and $x \rightarrow \frac{x}{2}$ we have $g(\hat{\theta_n}) = \frac{1}{n} \underset{i=1}{\overset{n}{\sum}} X_i$
#
# It means that $\hat{\theta_n} = \bar{X_n} \Leftrightarrow \hat{\theta_n} = 2*\bar{X_n}$
#
# **Remark 2**:
#
# We have $\mathbb{E}[X_1^2] = \mathbb{V}[X_1] + (\mathbb{E}[X_1])^2 = \frac{\theta^2}{12} + \frac{\theta^2}{4} = \frac{\theta^2}{3}$
#
# We have that an estimator $\hat{\theta_{n,2}}$ is a solution of $h(\hat{\theta_{n,2}}) = \frac{1}{n} \underset{i=1}{\overset{n}{\sum}} X_i^2$
#
# $\frac{\hat{\theta_{n,2}}^2}{3} = \frac{1}{n} \underset{i=1}{\overset{n}{\sum}} X_i$ thus $\theta_{n,2} = \sqrt{\frac{3}{n} * \underset{i=1}{\overset{n}{\sum}} X_i^2}$ assuming $\theta > 0$

# %% [markdown]
# **Remark 3**: In the method of moments, we can use the centered moments.
#
# The method is:
#
# 1. we find k such that $\mathbb{E}[(X - \mathbb{E}[X])^k] = g(\theta)$
# 2. an estimator $\hat{\theta_n}$ is such that $g(\hat{\theta_n}) = \frac{1}{n}\underset{i=1}{\overset{n}{\sum}}(X_i-\bar{X_n})^k$

# %% [markdown]
# **Application 2**:
#
# Let $X_1, ..., X_n$ IID rv. with distribution $U([-\theta,\theta])$. We have:
#
# - $\mathbb{E}[X_1] = 0$
# - $\mathbb{V}[X_1] = \frac{\theta^2}{3}$
#
# $\Rightarrow \hat{\theta_n^2} = \frac{1}{n}\underset{i=1}{\overset{n}{\sum}}(X_i-\bar{X_n})^2$
#
# $\Rightarrow \hat{\theta_n} = \sqrt{\frac{3}{n}\underset{i=1}{\overset{n}{\sum}}(X_i-\bar{X_n})^2}$

# %% [markdown]
# **Remark 4**:
#
# With the method of moments, we can construct several estimators for a same parameter.

# %% [markdown]
# ### Maximum Likelihood
#
# **The idea**:
#
# In the discrete case, we observe $x_1, ..., x_n$ that are realizations of $X_1, ..., X_n$ IID rv.
#
# We want to compute $P(X_1=x_1, ..., X_n=x_n) = \underset{i=1}{\overset{n}{\prod}}{P(X_i=x_i)} = f(\theta)$
#
# When we know the value of $\theta$, we look at the point $(x_1, ..., x_n)$ with the biggest probability.
#
# Because we observe $(x_1, ..., x_n)$, the estimator of $\theta$ will be the value such that the probability of observing $(x_1, ..., x_n)$ is maximal.
#
# **definition of the maximum likelihood estimator**:
#
# Let $X_1, ..., X_n$ IID rv. with distribution $P_{\theta}$. An estimator of $\theta$ by maximum likelihood is $\hat{\theta_n}$ such that $L(\hat{\theta_n}) = \underset{\theta}{max} L(\theta)$ where
#
# > $L$: The likelihood
# >
# > $L(\hat{\theta_n}) = L(X_1, ..., X_n, \theta)$
# >
# > $L(\hat{\theta_n}) = \underset{i=1}{\overset{n}{\prod}} P(X_i=x_i)\quad$ if $X_i$ are discrete
# >
# > $L(\hat{\theta_n}) = \underset{i=1}{\overset{n}{\prod}} f_{\theta}(X_i)\quad$ if $X_i$ are continuous

# %% [markdown]
# **Application 1**:
#
# Let $X_1, ..., X_n$ IID RV with distribution Bernouilli with parameter $p$. We want to estimate $p$.
#
# $L(p) = \underset{i=1}{\overset{n}{\prod}} P(X_i=x_i)$
#
# $P(X_i=0)=1-p$ and $P(X_i=1)=p \rightarrow P(X_i = x_i) =(1-p)^{1-x_i} * p^{x_i}$
#
# $L(p) = \underset{i=1}{\overset{n}{\prod}} (1-p)^{1-x_i} * p^{x_i}$
#
# $L(p) = \underset{i=1}{\overset{n}{\prod}} \frac{p}{1-p}^{\underset{i=1}{\overset{n}{\sum}} x_i} * (1-p)^n$
#
# We want to maximize this function as a function of $p$.
#
# In general, we do not maximize the likelihood but the log-likelihood.
#
# **Remark 1**:
#
# Log likelihood = lnL
#
# We denote by g this likelihood function
#
# $g(p) = lnL(P) = \sum x_i * ln(p/(1-p))+n*ln(1-p)$
#
# We want to maximize g and thus compute g'
#
# $ g'(p) = \sum x_i * (1/p + 1/(1-p))$ because $ln(1-p) = h(p) = f \rho l(p) with l(p) = 1-p and f(p) = ln(p)$
#
# $h'(p) = f'(l(p)) * l'(p)$
#
# $g'(p) = \sum x_i * \frac{1}{p*(1-p)} - \frac{n}{1-p}$
#
# we need to solve $g'(p) = 0$
#
# $\underset{i=1}{\overset{n}{\sum}} x_i . \frac{1}{p.(1-p)} - \frac{n}{1-p} = 0$
#
# $\underset{i=1}{\overset{n}{\sum}}\frac{x_i}{n} = p$
#
# We have to compute $g''$ and see if $g''(\underset{i=1}{\overset{n}{\sum}}\frac{x_i}{n}) < 0$
#
# We do not make the computation but it is the case
#
# we conclude that $\hat{p_n} = \underset{i=1}{\overset{n}{\sum}}\frac{X_i}{n}$ is the maximum likelihood estimator for p.

# %% [markdown]
# **Application 2**:
#
# Let $X_1, ..., X_n$ IID RV with distribution $E(\lambda)$
#
# $L(\lambda) = \underset{i=1}{\overset{n}{\prod}} f_{\lambda}(X_i) = \underset{i=1}{\overset{n}{\prod}} (\lambda * e^{-\lambda x_i} \mathbb{1}_{]0, +\infty[}(x_i)) = \lambda^n * e^{-\lambda\underset{i=1}{\overset{n}{\sum}}x_i} \mathbb{1}_{min(x_i) > 0}$ with $|_{min(x_i) > 0}$ which does not depend on $\lambda$
#
# We just need to maximize $h(\lambda) = \lambda^n*e^{-\lambda\underset{i=1}{\overset{n}{\sum}} x_i}$
#
# $l(\lambda) = ln(h(x)) = n * ln(\lambda) - \lambda \underset{i=1}{\overset{n}{\sum}} x_i = \frac{n}{\lambda} - \underset{i=1}{\overset{n}{\sum}} x_i$ then $l'(\lambda) = 0 \Leftrightarrow \lambda = \frac{n}{\underset{i=1}{\overset{n}{\sum}} x_i} = \frac{1}{\bar{x_n}}$
#
# Since we can see that $\frac{1}{\bar{x_n}}$ is associated to the maximization of the likelihood, we conclude the maximum likelihood estimator for $\lambda$ is $\hat{\lambda} = \frac{1}{\bar{X_n}}$
#
# **Remark 2**:
#
# If we apply the method of moments with the moment of order 1, we obtain the same result.

# %% [markdown]
# **Application 3**:
#
# Let $X_1, ..., X_n$ IID RV with $U([0,\theta])$/ What is the estimator of $\theta$?
#
# $L(\theta) = \underset{i=1}{\overset{n}{\prod}} \frac{1}{\theta} \mathbb{1}_{[0,\theta]} (x_i) = \frac{1}{\theta^n} \mathbb{1}_{min(x_i)\ge0} * \mathbb{1}_{max(x_i)\le\theta}$ We cannot make the maximization by making a derivation because $\mathbb{1}_{max(x_i)\le\theta}$ depends on $\theta$ but we can look into the behaviour.
#
# We conclude that in this case the maximum estimator of $\theta$ is $\hat{\theta_n} = max(X_i)$

# %% [markdown]
# **Exercise**:
#
# Let $X_1, ..., X_n$ IID RV with $U([0,\theta])$, we see that $\hat{\theta_n} = max(X_i)$ is an estimator of $\theta$.
#
# 1. Is $\hat{\theta_n}$ an unbiased estimator?
# 2. If not, deduce an unbiased estimator

# %% [markdown]
# ### Quadratic Error
#
# For an unknown parameter $\theta$, we can construct several estimators. How to know which is the best?
#
# **Definition**: Quadratic Error.
#
# Let $\hat{\theta_n}$ an estimator of $\theta$. The quadratic error of $\hat{\theta_n}$ is:
#
# $\mathbb{QE}(\hat{\theta_n}) = \mathbb{E}[(\hat{\theta_n}-\theta)^2]$
#
# **property:**
#
# $\mathbb{QE}[\hat{\theta_n}] = \mathbb{V}[\hat{\theta_n}] + (b(\hat{\theta_n}))^2$ with $b(\hat{\theta_n}) = E[\hat{\theta_n}] - \theta$
#
# **proof**:

# %%
Image("pictures/proof1.png", width=700)

# %% [markdown]
# $\mathbb{QE}[\hat{\theta_n}] = \mathbb{V}[\hat{\theta_n}] + 2b(\hat{\theta_n}) * \mathbb{E}[(\hat{\theta_n}-\mathbb{E}[\hat{\theta_n}])] + (b(\hat{\theta_n}))^2 =  \mathbb{V}[\hat{\theta_n}] + 2b(\hat{\theta_n}) *\mathbb{E}[(\hat{\theta_n}]-\mathbb{E}[\mathbb{E}[\hat{\theta_n}]] + (b(\hat{\theta_n}))^2 = \mathbb{V}[\hat{\theta_n}] + 2b(\hat{\theta_n}) * \mathbb{E}[(\hat{\theta_n}]-\mathbb{E}[\hat{\theta_n}] + (b(\hat{\theta_n}))^2 = \mathbb{V}[\hat{\theta_n}] + (b(\hat{\theta_n}))^2$
#
# **Remark 1**:
#
# If $\bar{\theta_n}$ is an unbiased estimator of $\theta$ then $b(\bar{\theta_n})$ and $\mathbb{QE}(\bar{\theta_n}) = V[\bar{\theta_n}]$.
#
# Because of the definition of the quadratic error, we prefer unbiased estimator with a small variance.

# %% [markdown]
# ### Comparison between 2 estimators
#
# Let $\hat{\theta_{n,1}}$ and $\hat{\theta_{n,2}}$ two estimators of $\theta$. if $\forall n, \mathbb{QE}(\hat{\theta_{n,1}}) \le \mathbb{QE}(\hat{\theta_{n,2}})$
#
# **Remark**: If we have two unbiased estimators for $\theta$, a way to get a better estimator consist in considering aggregated estimators. It means: $\bar{\theta_{n,1}}$ and $\bar{\theta_{n,2}}$ 2 estimators of $\theta$. $\bar{\theta_{n,3}} = a.\bar{\theta_{n,1}} + b.\bar{\theta_{n,2}}$.
#
# We find $\tilde{a}$ and $\tilde{b}$ such that $\mathbb{QE}(\tilde{a}.\bar{\theta_{n,1}} + \tilde{b}.\bar{\theta_{n,2}}) = \underset{a, b}{min}\,\mathbb{QE}(a.\bar{\theta_{n,1}} + b.\bar{\theta_{n,2}})$
#
# The best linear estimator constructed with $\hat{\theta_{n,1}}$ and $\hat{\theta_{n,2}}$ is $\tilde{a}.\hat{\theta_{n,1}} + \tilde{b}.\hat{\theta_{n,2}}$

# %% [markdown]
# **Exercise**:
#
# Let $X_1, ..., X_n$ IID RV with $U([0,\theta])$
#
# 1. $\hat{\theta_{n,1}} = 2*\bar{X_n}$ Compute the quadratic error of $\hat{\theta_{n,1}}$
# 2. $\hat{\theta_{n,2}}$ ther unbiased version of $Max(X_i)$ Compute the quadratic error of $\hat{\theta_{n,2}}$
# 3. Which one is the better one?

# %% [markdown]
# ## Drawback of Point Estimation
#
# Point estimation has a main drawback. It is **fluctuating** due to the sample.
#
# <u>Illustration of the phenomenon:</u>
#
# Let $X_1, ..., X_n$ IID RV with distribution $N(\mu, \sigma^2)$. We want to estimate $\mu$ i.e. $\mu = \bar{X_n}$.
#
# We perform simulations. We create 50 datasets associated to $X_1, ..., X_n$ and on each of them we compute a value of $\hat{\mu_n}$.
#
# To have a quantification of the quality of the estimation, we prefer a **confidence interval**.

# %% [markdown]
# ## Confidence Interval
#
# A confidence Interval is a **random object**. To a confidence interval is associated a **confidence level**.
#
# This confidence level is generally denoted ``100 * (1-alpha)%``
#
# **Definition**:
#
# Let $X_1, ..., X_n$ IID RV with distribution $P_\theta$. Let $\hat{\theta_n}$ an estimator of $\theta$.
#
# A confidence interval, based on $\hat{\theta_n}$, with confidence level $100 * (1-\alpha)\%$ is a random interval $[A_n, B_n]$ such that:
#
# - $A_n = f_1(\hat{\theta_n})$ and $B_n = f_2(\hat{\theta_n})$
# - $P(\theta \in [A_n, B_n]) = 1-\alpha$
#
# **Remark 1**:
#
# More and more $\alpha$ is small, the more and more the confidence level is close to 1, and the length of the confidence interval is big.

# %% [markdown]
# **How to construct such confidence interval**?
#
# 1. $X_1, ..., X_n$ are IID RV with a distribution $N(\mu, \sigma^2)$ and we assume $\mu$ is unknown and $\sigma^2$ is known.
# 2. We need at first a point estimator for $\mu$ i.e. $\mu = \bar{X_n}$
#
# $$\bar{X_n} \sim N(\mu, \sigma^2)$$
#
# 3. We want to find $A_n$ and $B_n$ RV that are functions of $\bar{X_n}$ such that $P(A_n \le \mu \le B_n) = 1-\alpha$
#
# We make the choice $A_n = \bar{X_n} - S_n$ and $B_n = \bar{X_n} + T_n$
#
# We need to find $S_n$ and $T_n$ such that:
#
# $P(\bar{X_n} - S_n \le \mu \le \bar{X_n} + T_n) = 1-\alpha \Leftrightarrow P(- T_n \le \bar{X_n} - \mu \le S_n) = 1-\alpha$
#
# We know $ \bar{X_n} - \mu \sim N(0, \frac{\sigma^2}{n}) \Leftrightarrow P(\frac{-\sqrt{n}*T_n}{\sigma} \le \sqrt{n} * \frac{\bar{X_n}-\mu}{\sigma} \le \frac{\sqrt(n)*S_n}{\sigma}) = 1-\alpha$
#
# Several solutions exist because we have 2 quantities to determine with just one equation. We have to make a choice.
#
# $y_n = \sqrt{n} * \frac{\bar{X_n}-\mu}{\sigma}$
#
# $P(y_n \lt \frac{-\sqrt(n)*T_n}{\sigma}) + P(y_n \gt \frac{\sqrt{n}*S_n}{\sigma}) = \alpha_1 + \alpha_2 = \alpha$
#
# #### 3 main choices:
# <hr>
#
# **1.** $\alpha_1 = \alpha_2 = \alpha/2$
#
# We have $P(y_n \lt \frac{-\sqrt(n)*T_n}{\sigma}) = P(y_n \gt \frac{\sqrt(n)*S_n}{\sigma}) =\alpha/2$.
#
# One solution is to take $\frac{\sqrt{n}*S_n}{\sigma} = quantile\, of\, order\, (1-\frac{\alpha}{2})\, for\, N(0,1)$. We denote this quantile by $Z_{1-\frac{\alpha}{2}}$ and $S_n = \frac{\sigma}{\sqrt{n}}*Z_{1-\frac{\alpha}{2}}$
#
# Confidence interval for \mu at level $100*(1-\alpha)\%$ is $[\bar{X_n}-\frac{\sigma}{\sqrt{n}}*Z_{1-\frac{\alpha}{2}}, \bar{X_n}+\frac{\sigma}{\sqrt{n}}*Z_{1-\frac{\alpha}{2}}]$
# <hr>
#
# **2.** $\alpha_1 = 0$ and $\alpha_1 = \alpha$
#
# $P(y_n \lt \frac{-\sqrt(n)*T_n}{\sigma}) = 0$ and $P(y_n \gt \frac{\sqrt{n}*S_n}{\sigma}) = \alpha$
#
# This implies $T_n = -\infty$ and $P(y_n \gt \frac{\sqrt{n}*S_n}{\sigma}) \Leftrightarrow P(y_n \le \frac{\sqrt{n}*S_n}{\sigma}) = 1-\alpha$ which implies $\frac{\sqrt{n}*S_n}{\sigma} = Z_{1-\alpha}$
#
# In this case, the confidence interval becomes $[\bar{X_n} - \frac{\sigma}{\sqrt{n}}*Z_{1-\alpha}, +\infty]$
# <hr>
#
# **3.** $\alpha_1 = \alpha$ and $\alpha_1 = 0$
#
# In this case, the confidence interval becomes $[-\infty, \bar{X_n} + \frac{\sigma}{\sqrt{n}}*Z_{1-\alpha}]$
#
# More generaly, you take $\alpha_1 \ge 0$, $\alpha_2 \ge 0$ such that $\alpha_1 + \alpha_2 = \alpha$ and:

# %%
Image("pictures/picture2.png", width=700)

# %% [markdown]
# The associated confidence interval is $[\bar{X_n} - \frac{\sigma}{\sqrt{n}}*Z_{1-\alpha_2}, \bar{X_n} - \frac{\sigma}{\sqrt{n}}*Z_{1-\alpha_1}] $. The length of the confidence interval is $\frac{\sigma}{\sqrt{n}}*(Z_{1-\alpha_2}+Z_{1-\alpha_1})$
