# %% [markdown]
# # Getting data from Google Cloud Storage
#
# First, you need to use a `gsutil` command (which is usually pre-installed on machines created in Google Cloud).
#
# Second, you need an address of a bucket (where data is stores) and path to the file you need in that bucket (usually you receive them when the owner of the data gives you permissions).
#
# Third, you need need permissions to this particular bucket (or even this particular object if the access to bucket is fine-grained).
#
# Disclaimer. Downloading large amounts of data can take time:)

# %%
# !mkdir /home/user/Downloads

# %%
# !ls /home/user/Downloads

# %%
# !gsutil cp gs://yelp-dataset-bucket/yelp_academic_dataset_review.json /home/user/Downloads
# Out:
# Copying gs://yelp-dataset-bucket/yelp_academic_dataset_review.json...
# - [1 files][  5.9 GiB/  5.9 GiB]   54.7 MiB/s
# Operation completed over 1 objects/5.9 GiB.

# %% [markdown]
# We also will download example notebooks from the cloud storage

# %%
# !gsutil cp gs://yelp-dataset-bucket/working-with-hdfs.ipynb /home/user/Downloads
# !gsutil cp gs://yelp-dataset-bucket/map-reduce.ipynb /home/user/Downloads
# !gsutil cp gs://yelp-dataset-bucket/mapper.py /home/user/Downloads
# !gsutil cp gs://yelp-dataset-bucket/reducer.py /home/user/Downloads
# Out:
# Copying gs://yelp-dataset-bucket/working-with-hdfs.ipynb...
# / [1 files][  8.1 KiB/  8.1 KiB]
# Operation completed over 1 objects/8.1 KiB.
# Copying gs://yelp-dataset-bucket/map-reduce.ipynb...
# / [1 files][ 15.6 KiB/ 15.6 KiB]
# Operation completed over 1 objects/15.6 KiB.
# Copying gs://yelp-dataset-bucket/mapper.py...
# / [1 files][  139.0 B/  139.0 B]
# Operation completed over 1 objects/139.0 B.
# Copying gs://yelp-dataset-bucket/reducer.py...
# / [1 files][  150.0 B/  150.0 B]
# Operation completed over 1 objects/150.0 B.

# %%
# !cat /home/user/Downloads/mapper.py
# Out:
# #!/usr/bin/python
#
# counter = 0
# while True:
#     try:
#         counter += 1
#         input()
#     except EOFError:
#         break
# print(counter)

# %%
# !cat /home/user/Downloads/reducer.py
# Out:
# #!/usr/bin/python
#
# counter = 0
# while True:
#     try:
#         line = input()
#     except EOFError:
#         break
#     counter += int(line)
# print(counter)

# %%
# !head /home/user/Downloads/yelp_academic_dataset_review.json
# Out:
# {"review_id":"xQY8N_XvtGbearJ5X4QryQ","user_id":"OwjRMXRC0KyPrIlcjaXeFQ","business_id":"-MhfebM0QIsKt87iDN-FNw","stars":2.0,"useful":5,"funny":0,"cool":0,"text":"As someone who has worked with many museums, I was eager to visit this gallery on my most recent trip to Las Vegas. When I saw they would be showing infamous eggs of the House of Faberge from the Virginia Museum of Fine Arts (VMFA), I knew I had to go!\n\nTucked away near the gelateria and the garden, the Gallery is pretty much hidden from view. It's what real estate agents would call \"cozy\" or \"charming\" - basically any euphemism for small.\n\nThat being said, you can still see wonderful art at a gallery of any size, so why the two *s you ask? Let me tell you:\n\n* pricing for this, while relatively inexpensive for a Las Vegas attraction, is completely over the top. For the space and the amount of art you can fit in there, it is a bit much.\n* it's not kid friendly at all. Seriously, don't bring them.\n* the security is
# ...

# %% [markdown]
# ## Workshop
