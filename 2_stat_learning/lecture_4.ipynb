# %% [markdown]
# # Statistical Learning - lecture 4

# %%
from IPython.display import Image

# %% [markdown]
# For a fixed $h \in H$.
#
# $$R(|\hat{R}_s(h) = R_D(h)|\gt\epsilon)$$
#
# **Hoeffding inequality**: $\forall Z_1, ..., Z_n \in [a,b]$
# $$E[Z_1]=\mu$$
# $$(|\frac{1}{n}\overset{n}{\underset{i=1}{\sum}}Z_i-\mu|\gt\epsilon ) \lt 2.e^{\frac{-2.n.\epsilon^2}{(b-a)^2}}$$
#
# $\forall (x_1, y_1), ..., (x_n, y_n) IID \Rightarrow (l(y_i, h(x_1))_{i\in 1, ..., n} IID$
# $l(y, y')\in [a, b] (a=0, b=1)$
#
# - 0-1 loss
# - $y = (1, ..., k)$
# - $l(y, y') = (y-y')^2, y \in \mathbb{R}$
#
# $$\hat{R}_S(h) = \frac{1}{n}{\underset{i=1}{\sum}}l(y)i,h(x_i)= \frac{1}{n}{\underset{i=1}{\sum}}Z_i$$
#
# $$R(|\hat{R}_s(h) = R_D(h)|\gt\epsilon)\lt 2.e^{\frac{-2.n.\epsilon^2}{(b-a)^2}}$$

# %%
Image('pictures/boundingR.png', width=600)

# %%
Image('pictures/inequality.png', width=600)

# %%
Image('pictures/recap.png', width=600)

# %%
Image('pictures/approxerror.png', width=600)

# %% [markdown]
# ## Vapnik-Chervonenkis Dimension
#
# - Finite H are PAC learnable
# - Sample complexity grows as log(H)
#
# **Question**: What happens for infinite classes?
#
# $\Rightarrow$ VC dimension is one possible notion of complexity of the class H (introduction in the setting of binary classification).
