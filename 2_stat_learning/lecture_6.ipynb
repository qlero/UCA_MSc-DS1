# %% [markdown]
# # Statistical Learning - lecture 6

# %%
from IPython.display import Image

# %%
Image('pictures/empirical_risk_minimization.png', width=600)

# %%
Image('pictures/derivation.png', width=600)
